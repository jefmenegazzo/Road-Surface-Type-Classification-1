# %% [markdown]
# <h1>CNN - Processing</h1>

# %% [markdown]
# <h5>Importing Packages</h5>

# %%
useKerasTfV1=True
useKerasTfV2=False
useTfV2=False

# %%
try:
    from google.colab import drive
    drive.mount('/drive', force_remount=False)
    # %run "/drive/My Drive/Colab Notebooks/Notebooks/Deep Learning/Deep Learning - Processing.ipynb"
except:
    # %run "/Google Drive/Colab Notebooks/Notebooks/Deep Learning/Deep Learning - Processing.ipynb"

# %% [markdown]
# <h5>Models</h5>

# %%
def model1(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 1"

def model2(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 2"

def model3(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(BatchNormalization())
    model.add(Dropout(0.15))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(GlobalAvgPool1D())
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 3"

# https://www.sciencedirect.com/science/article/pii/S0966636219307064
def model4(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=100, kernel_size=10, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(Conv1D(filters=100, kernel_size=10, activation='relu'))
    model.add(MaxPooling1D(pool_size=3))
    model.add(Conv1D(filters=160, kernel_size=10, activation='relu'))
    model.add(Conv1D(filters=160, kernel_size=10, activation='relu'))
    model.add(GlobalAvgPool1D())
    model.add(Dropout(0.5))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 4"

# https://ieeexplore.ieee.org/document/8559719
def model5(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(Flatten())
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 5"

# https://blogs.rstudio.com/tensorflow/posts/2018-07-17-activity-detection/
def model6(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=24, kernel_size=8, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(BatchNormalization())
    model.add(SpatialDropout1D(0.15))
    model.add(Conv1D(filters=12, kernel_size=8, activation='relu'))
    model.add(GlobalAvgPool1D())
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(48, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 6"

# https://ieeexplore.ieee.org/document/8834480
def model7(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN 7"

# %%
def bestModel(n_convolutional, n_features, n_outputs):
    model = Sequential()
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_convolutional, n_features)))
    model.add(BatchNormalization())
    model.add(Dropout(0.15))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.15))
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(GlobalAvgPool1D())
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(n_outputs, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])
    return model, "CNN/CNN Best Model"

# %%
def parameters(input_shape, output_shape):

    return {
        "n_convolutional": input_shape[1], 
        "n_features": input_shape[2], 
        "n_outputs": output_shape[1]
    }

# %% [markdown]
# <h5>Parameters</h5>

# %%
datasets = getDataSets()

# %%
# sides = ['left']
sides = ['left', 'right']
mode_label = True
# moving_window = True
moving_window = False
fields = experiment_by_fields[2]
subsets = getSubSets(datasets, fields, surface_type_labels)

# %%
# (function, args, scaler name)
scalers = [
    # (getNormalizedDataRobust, None, "robust-scaler"),
    (getNormalizedDataMinMax, (-1,1), "min-max-scaler"),
    # (getNormalizedDataMinMax, (0,1), "min-max-scaler")
]

# (shape, window size)
input_shapes = [
    ((None, 100, 7), 100), 
    ((None, 150, 7), 150), 
    ((None, 200, 7), 200), 
    ((None, 250, 7), 250), 
    ((None, 300, 7), 300)
]

output_shape = (None, 3)

# %% [markdown]
# <h5>Training</h5>

# %%
getLoadBar()

# %%
run(bestModel, patience=50)

# %%
run(model1, patience=50)

# %%
run(model2, patience=50)

# %%
run(model3, patience=50)

# %%
run(model4, patience=50)

# %%
run(model5, patience=50)

# %%
run(model6, patience=50)

# %%
run(model7, patience=50)

# %% [markdown]
# <h5>Confusion Matrix - Best Model</h5>

# %%
files = [
    'experiment-1-window-300-scaler-min-max-scaler-(-1, 1)-train-acc-0.94390-val-acc-0.94933.hdf5',
    'experiment-2-window-300-scaler-min-max-scaler-(-1, 1)-train-acc-0.97617-val-acc-0.92254.hdf5',
    'experiment-3-window-300-scaler-min-max-scaler-(-1, 1)-train-acc-0.94669-val-acc-0.92333.hdf5'
]

# %%
confusionMatrix(files, "CNN-based DNN", bestModel, (None, 300, 7), (None, 3), getNormalizedDataMinMax, (-1,1))
# Out:
# 0.9493322859387274
# 0.9225352112676056
# 0.9233278955954323

# %%
classificationReport(files, bestModel, (None, 300, 7), (None, 3), getNormalizedDataMinMax, (-1,1))
# Out:
# {'accuracy': 0.9320021586616298,
#  'asphalt_road': {'f1-score': 0.989645434577973,
#   'precision': 0.9899560577526679,
#   'recall': 0.9893350062735258,
#   'support': 3188},
#  'cobblestone_road': {'f1-score': 0.8584123222748816,
#   'precision': 0.8922413793103449,
#   'recall': 0.827054794520548,
#   'support': 1752},
#  'dirt_road': {'f1-score': 0.9085534095388254,
#   'precision': 0.8858570330514989,
#   'recall': 0.9324433656957929,
#   'support': 2472},
#  'macro avg': {'f1-score': 0.9188703887972266,
#   'precision': 0.9226848233715038,
#   'recall': 0.9162777221632888,
#   'support': 7412},
#  'weighted avg': {'f1-score': 0.9315801487372027,
#   'precision': 0.932140501129322,
#   'recall': 0.9320021586616298,
#   'support': 7412}}
